# %%
# %matplotlib widget

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import os
from keras import optimizers
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
from keras import regularizers
import matplotlib.pyplot as plt

def load_X(X_path):
    file = open(X_path, 'r')
    X_ = np.array(
        [elem for elem in [
            row.split(',') for row in file
        ]], 
        dtype=np.float32
    )
    file.close()
    return X_

def load_Y(y_path):
    file = open(y_path, 'r')
    y_ = np.array(
        [elem for elem in [
            row.replace('  ', ' ').strip().split(' ') for row in file
        ]], 
        dtype=np.int32
    )
    file.close()
    return y_

# %%
def euclidean_dist(a, b):
    # This function calculates the euclidean distance between 2 point in 2-D coordinates
    # if one of two points is (0,0), dist = 0
    # a, b: input array with dimension: m, 2
    # m: number of samples
    # 2: x and y coordinate
    try:
        if (a.shape[1] == 2 and a.shape == b.shape):
            # check if element of a and b is (0,0)
            bol_a = (a[:,0] != 0).astype(int)
            bol_b = (b[:,0] != 0).astype(int)
            dist = np.linalg.norm(a-b, axis=1)
            return((dist*bol_a*bol_b).reshape(a.shape[0],1))
    except:
        print("[Error]: Check dimension of input vector")
        return 0

# %%
def norm_X(X):
    num_sample = X.shape[0]
    # Keypoints
    Nose = X[:,0*2:0*2+2]
    Neck = X[:,1*2:1*2+2]
    RShoulder = X[:,2*2:2*2+2]
    RElbow = X[:,3*2:3*2+2]
    RWrist = X[:,4*2:4*2+2]
    LShoulder = X[:,5*2:5*2+2]
    LElbow = X[:,6*2:6*2+2]
    LWrist = X[:,7*2:7*2+2]
    RHip = X[:,8*2:8*2+2]
    RKnee = X[:,9*2:9*2+2]
    RAnkle = X[:,10*2:10*2+2]
    LHip = X[:,11*2:11*2+2]
    LKnee = X[:,12*2:12*2+2]
    LAnkle = X[:,13*2:13*2+2]
    REye = X[:,14*2:14*2+2]
    LEye = X[:,15*2:15*2+2]
    REar = X[:,16*2:16*2+2]
    LEar = X[:,17*2:17*2+2]

    # Length of head
    length_Neck_LEar = euclidean_dist(Neck, LEar)
    length_Neck_REar = euclidean_dist(Neck, REar)
    length_Neck_LEye = euclidean_dist(Neck, LEye)
    length_Neck_REye = euclidean_dist(Neck, REye)
    length_Nose_LEar = euclidean_dist(Nose, LEar)
    length_Nose_REar = euclidean_dist(Nose, REar)
    length_Nose_LEye = euclidean_dist(Nose, LEye)
    length_Nose_REye = euclidean_dist(Nose, REye)
    length_head      = np.maximum.reduce([length_Neck_LEar, length_Neck_REar, length_Neck_LEye, length_Neck_REye, \
                                 length_Nose_LEar, length_Nose_REar, length_Nose_LEye, length_Nose_REye])
    #length_head      = np.sqrt(np.square((LEye[:,0:1]+REye[:,0:1])/2 - Neck[:,0:1]) + np.square((LEye[:,1:2]+REye[:,1:2])/2 - Neck[:,1:2]))

    # Length of torso
    length_Neck_LHip = euclidean_dist(Neck, LHip)
    length_Neck_RHip = euclidean_dist(Neck, RHip)
    length_torso     = np.maximum(length_Neck_LHip, length_Neck_RHip)
    #length_torso     = np.sqrt(np.square(Neck[:,0:1]-(LHip[:,0:1]+RHip[:,0:1])/2) + np.square(Neck[:,1:2]-(LHip[:,1:2]+RHip[:,1:2])/2))

    # Length of right leg
    length_leg_right = euclidean_dist(RHip, RKnee) + euclidean_dist(RKnee, RAnkle)
    #length_leg_right = np.sqrt(np.square(RHip[:,0:1]-RKnee[:,0:1]) + np.square(RHip[:,1:2]-RKnee[:,1:2])) \
    #+ np.sqrt(np.square(RKnee[:,0:1]-RAnkle[:,0:1]) + np.square(RKnee[:,1:2]-RAnkle[:,1:2]))

    # Length of left leg
    length_leg_left = euclidean_dist(LHip, LKnee) + euclidean_dist(LKnee, LAnkle)
    #length_leg_left = np.sqrt(np.square(LHip[:,0:1]-LKnee[:,0:1]) + np.square(LHip[:,1:2]-LKnee[:,1:2])) \
    #+ np.sqrt(np.square(LKnee[:,0:1]-LAnkle[:,0:1]) + np.square(LKnee[:,1:2]-LAnkle[:,1:2]))

    # Length of leg
    length_leg = np.maximum(length_leg_right, length_leg_left)

    # Length of body
    length_body = length_head + length_torso + length_leg
    
    # Check all samples have length_body of 0
    length_chk = (length_body > 0).astype(int)
    
    # Check keypoints at origin
    keypoints_chk = (X > 0).astype(int)
    
    chk = length_chk * keypoints_chk
    
    # Set all length_body of 0 to 1 (to avoid division by 0)
    length_body[length_body == 0] = 1
    
    # The center of gravity
    # number of point OpenPose locates:
    num_pts = (X[:, 0::2] > 0).sum(1).reshape(num_sample,1)
    centr_x = X[:, 0::2].sum(1).reshape(num_sample,1) / num_pts
    centr_y = X[:, 1::2].sum(1).reshape(num_sample,1) / num_pts

    # The  coordinates  are  normalized relative to the length of the body and the center of gravity
    X_norm_x = (X[:, 0::2] - centr_x) / length_body
    X_norm_y = (X[:, 1::2] - centr_y) / length_body
    
    # Stack 1st element x and y together
    X_norm = np.column_stack((X_norm_x[:,:1], X_norm_y[:,:1]))
        
    for i in range(1, X.shape[1]//2):
        X_norm = np.column_stack((X_norm, X_norm_x[:,i:i+1], X_norm_y[:,i:i+1]))
    
    # Set all samples have length_body of 0 to origin (0, 0)
    X_norm = X_norm * chk
    
    return X_norm

# %%
def plot_line(a, b):
    if (a.any()> 0 and b.any()>0): plt.plot([a[0], b[0]], [a[1], b[1]], 'k-')
        
def plot_skeleton(sample, pattern):
    for i in range(len(sample)//2):
        plt.plot(sample[i*2], sample[i*2+1], pattern) 
    skeleton = sample.reshape(1, 36)
    Nose = skeleton[:,0*2:0*2+2][0]
    Neck = skeleton[:,1*2:1*2+2][0]
    RShoulder = skeleton[:,2*2:2*2+2][0]
    RElbow = skeleton[:,3*2:3*2+2][0]
    RWrist = skeleton[:,4*2:4*2+2][0]
    LShoulder = skeleton[:,5*2:5*2+2][0]
    LElbow = skeleton[:,6*2:6*2+2][0]
    LWrist = skeleton[:,7*2:7*2+2][0]
    RHip = skeleton[:,8*2:8*2+2][0]
    RKnee = skeleton[:,9*2:9*2+2][0]
    RAnkle = skeleton[:,10*2:10*2+2][0]
    LHip = skeleton[:,11*2:11*2+2][0]
    LKnee = skeleton[:,12*2:12*2+2][0]
    LAnkle = skeleton[:,13*2:13*2+2][0]
    REye = skeleton[:,14*2:14*2+2][0]
    LEye = skeleton[:,15*2:15*2+2][0]
    REar = skeleton[:,16*2:16*2+2][0]
    LEar = skeleton[:,17*2:17*2+2][0]
    #Nose = sample.reshape(1, 36)[:,0*2:0*2+2][0]
    #Neck = sample.reshape(1, 36)[:,1*2:1*2+2][0]
    plot_line(LEar, LEye)
    plot_line(LEye, Nose)
    plot_line(REar, REye)
    plot_line(REye, Nose)
    plot_line(Nose, Neck)
    plot_line(Neck, LShoulder)
    plot_line(LShoulder, LElbow)
    plot_line(LElbow, LWrist)
    plot_line(Neck, RShoulder)
    plot_line(RShoulder, RElbow)
    plot_line(RElbow, RWrist)
    plot_line(Neck, LHip)
    plot_line(LHip, LKnee)
    plot_line(LKnee, LAnkle)
    plot_line(Neck, RHip)
    plot_line(RHip, RKnee)
    plot_line(RKnee, RAnkle)
    
def plot(sample):
    # sample is one-dimension array
    # e.g: (36,)
    if sample.shape[0] == 36:
        sample_norm = norm_X(sample.reshape(1,36))[0]

        # Plot original coordinates
        pad_ori = 40
        plt.figure(str(sample))
        plt.subplot(121)
        plt.title('Original skeleton')
        X_ori = sample
        x_max = max(X_ori[0::2]) + pad_ori
        x_min = min(i for i in X_ori[0::2] if i > 0) - pad_ori
        y_max = max(X_ori[1::2]) + pad_ori
        y_min = min(j for j in X_ori[1::2] if j > 0) - pad_ori
        plt.xlim(x_min,x_max)
        plt.ylim(y_max, y_min)
        plot_skeleton(X_ori, 'bo')

        # Plot normalized coordinates
        pad_nor = 0.2
        #plt.figure(2)
        plt.subplot(122)
        plt.title('Normalized skeleton')
        X_nor = sample_norm
        x_max = max(X_nor[0::2]) + pad_nor
        x_min = min(X_nor[0::2]) - pad_nor
        y_max = max(X_nor[1::2]) + pad_nor
        y_min = min(X_nor[1::2]) - pad_nor
        plt.xlim(x_min,x_max)
        plt.ylim(y_max, y_min)
        plot_skeleton(X_nor, 'ro')
    else:
        print("sample is one-dimension array: (36,)")

# %%
# Create a model
model = keras.Sequential([
    keras.layers.Dense(64, activation='sigmoid', input_shape=(36,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(32, activation='sigmoid'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='sigmoid'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(3, activation='softmax')
])
model.summary()

# plot training log
def plot_history(history):
    history_dict = history.history
    history_dict.keys()
    acc = history.history['acc']
    val_acc = history.history['val_acc']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(1, len(acc) + 1)

    # "bo" is for "blue dot"
    plt.plot(epochs, loss, 'bo', label='Training loss')
    plt.plot(epochs, acc, 'b', label='Training accuracy')
    # b is for "solid blue line"
    plt.plot(epochs, val_loss, 'ro', label='Validation loss')
    plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
    plt.title('Training and validation loss/acc')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 64)                2368
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                528
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 5,027
# Trainable params: 5,027
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=keras.losses.sparse_categorical_crossentropy, optimizer=keras.optimizers.Adam(lr=0.01), metrics=['accuracy'])

# %%
# Load and norminalize dataset
X_train = load_X('dataset/X_train.txt')
Y_train = load_Y('dataset/Y_train.txt')
X_train_norm = norm_X(X_train)

X_test = load_X('dataset/X_test.txt')
Y_test = load_Y('dataset/Y_test.txt')
X_test_norm = norm_X(X_test)

# %%
history = model.fit(X_train_norm, Y_train, validation_data=(X_test_norm, Y_test), epochs=500, batch_size=32, verbose=1)#, callbacks= [earlyStopping])
# Out:
# Train on 2676 samples, validate on 701 samples
# Epoch 1/500
# 2676/2676 [==============================] - 0s 89us/sample - loss: 1.1054 - acc: 0.3774 - val_loss: 0.9880 - val_acc: 0.4365
# Epoch 2/500
# 2676/2676 [==============================] - 0s 46us/sample - loss: 0.8946 - acc: 0.5583 - val_loss: 0.6901 - val_acc: 0.7118
# Epoch 3/500
# 2676/2676 [==============================] - 0s 44us/sample - loss: 0.7305 - acc: 0.6611 - val_loss: 0.5362 - val_acc: 0.8017
# Epoch 4/500
# 2676/2676 [==============================] - 0s 43us/sample - loss: 0.6053 - acc: 0.7590 - val_loss: 0.4576 - val_acc: 0.8146
# Epoch 5/500
# 2676/2676 [==============================] - 0s 43us/sample - loss: 0.5481 - acc: 0.7881 - val_loss: 0.4012 - val_acc: 0.8402
# Epoch 6/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.5138 - acc: 0.8102 - val_loss: 0.3515 - val_acc: 0.8474
# Epoch 7/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.4788 - acc: 0.8285 - val_loss: 0.3140 - val_acc: 0.8902
# Epoch 8/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.4475 - acc: 0.8427 - val_loss: 0.2826 - val_acc: 0.9073
# Epoch 9/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.4562 - acc: 0.8460 - val_loss: 0.2629 - val_acc: 0.9001
# Epoch 10/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.4023 - acc: 0.8617 - val_loss: 0.2434 - val_acc: 0.9087
# Epoch 11/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.4132 - acc: 0.8741 - val_loss: 0.2515 - val_acc: 0.9030
# Epoch 12/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3937 - acc: 0.8685 - val_loss: 0.2359 - val_acc: 0.9087
# Epoch 13/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.4014 - acc: 0.8707 - val_loss: 0.2363 - val_acc: 0.9073
# Epoch 14/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3835 - acc: 0.8741 - val_loss: 0.2352 - val_acc: 0.9144
# Epoch 15/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3682 - acc: 0.8729 - val_loss: 0.2281 - val_acc: 0.9101
# Epoch 16/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3666 - acc: 0.8812 - val_loss: 0.2378 - val_acc: 0.9130
# Epoch 17/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3414 - acc: 0.8842 - val_loss: 0.2294 - val_acc: 0.9130
# Epoch 18/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3824 - acc: 0.8729 - val_loss: 0.2205 - val_acc: 0.9116
# Epoch 19/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3577 - acc: 0.8748 - val_loss: 0.2317 - val_acc: 0.9130
# Epoch 20/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3491 - acc: 0.8931 - val_loss: 0.2258 - val_acc: 0.9158
# Epoch 21/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3659 - acc: 0.8804 - val_loss: 0.2229 - val_acc: 0.9116
# Epoch 22/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.3480 - acc: 0.8838 - val_loss: 0.2275 - val_acc: 0.9130
# Epoch 23/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3268 - acc: 0.8969 - val_loss: 0.2256 - val_acc: 0.9144
# Epoch 24/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3539 - acc: 0.8827 - val_loss: 0.2214 - val_acc: 0.9144
# Epoch 25/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3363 - acc: 0.8898 - val_loss: 0.2210 - val_acc: 0.9173
# Epoch 26/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3326 - acc: 0.8916 - val_loss: 0.2216 - val_acc: 0.9201
# Epoch 27/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3359 - acc: 0.8961 - val_loss: 0.2180 - val_acc: 0.9144
# Epoch 28/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3130 - acc: 0.8972 - val_loss: 0.2143 - val_acc: 0.9244
# Epoch 29/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3267 - acc: 0.8995 - val_loss: 0.2110 - val_acc: 0.9201
# Epoch 30/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.3315 - acc: 0.8883 - val_loss: 0.2110 - val_acc: 0.9144
# Epoch 31/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3253 - acc: 0.8939 - val_loss: 0.2096 - val_acc: 0.9144
# Epoch 32/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3124 - acc: 0.9032 - val_loss: 0.2119 - val_acc: 0.9144
# Epoch 33/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3270 - acc: 0.8976 - val_loss: 0.2094 - val_acc: 0.9201
# Epoch 34/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.3089 - acc: 0.9021 - val_loss: 0.2155 - val_acc: 0.9144
# Epoch 35/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.3231 - acc: 0.8984 - val_loss: 0.2058 - val_acc: 0.9144
# Epoch 36/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.3052 - acc: 0.8991 - val_loss: 0.2085 - val_acc: 0.9187
# Epoch 37/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3210 - acc: 0.8999 - val_loss: 0.2073 - val_acc: 0.9173
# Epoch 38/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2989 - acc: 0.9010 - val_loss: 0.2097 - val_acc: 0.9173
# Epoch 39/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3044 - acc: 0.9006 - val_loss: 0.2072 - val_acc: 0.9173
# Epoch 40/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2686 - acc: 0.9047 - val_loss: 0.2085 - val_acc: 0.9144
# Epoch 41/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3195 - acc: 0.8987 - val_loss: 0.2097 - val_acc: 0.9201
# Epoch 42/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3064 - acc: 0.8969 - val_loss: 0.2055 - val_acc: 0.9144
# Epoch 43/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3102 - acc: 0.9006 - val_loss: 0.2001 - val_acc: 0.9187
# Epoch 44/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.3014 - acc: 0.9006 - val_loss: 0.2111 - val_acc: 0.9201
# Epoch 45/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2965 - acc: 0.9066 - val_loss: 0.2188 - val_acc: 0.9130
# Epoch 46/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2886 - acc: 0.9032 - val_loss: 0.1986 - val_acc: 0.9173
# Epoch 47/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2925 - acc: 0.9032 - val_loss: 0.2131 - val_acc: 0.9158
# Epoch 48/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2824 - acc: 0.9159 - val_loss: 0.2114 - val_acc: 0.9130
# Epoch 49/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2780 - acc: 0.9055 - val_loss: 0.2101 - val_acc: 0.9130
# Epoch 50/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2869 - acc: 0.9081 - val_loss: 0.2056 - val_acc: 0.9144
# Epoch 51/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2960 - acc: 0.8995 - val_loss: 0.2033 - val_acc: 0.9158
# Epoch 52/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2840 - acc: 0.9088 - val_loss: 0.1929 - val_acc: 0.9173
# Epoch 53/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2748 - acc: 0.9077 - val_loss: 0.2031 - val_acc: 0.9173
# Epoch 54/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2673 - acc: 0.9133 - val_loss: 0.2019 - val_acc: 0.9173
# Epoch 55/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2845 - acc: 0.9073 - val_loss: 0.1977 - val_acc: 0.9187
# Epoch 56/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2760 - acc: 0.9118 - val_loss: 0.2019 - val_acc: 0.9144
# Epoch 57/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2972 - acc: 0.9021 - val_loss: 0.1973 - val_acc: 0.9173
# Epoch 58/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2835 - acc: 0.9084 - val_loss: 0.1975 - val_acc: 0.9144
# Epoch 59/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2860 - acc: 0.9070 - val_loss: 0.2035 - val_acc: 0.9158
# Epoch 60/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2879 - acc: 0.9070 - val_loss: 0.2055 - val_acc: 0.9173
# Epoch 61/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2600 - acc: 0.9208 - val_loss: 0.1888 - val_acc: 0.9144
# Epoch 62/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2891 - acc: 0.8995 - val_loss: 0.1994 - val_acc: 0.9144
# Epoch 63/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2919 - acc: 0.9043 - val_loss: 0.1937 - val_acc: 0.9173
# Epoch 64/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2640 - acc: 0.9167 - val_loss: 0.1810 - val_acc: 0.9187
# Epoch 65/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2838 - acc: 0.9092 - val_loss: 0.1761 - val_acc: 0.9215
# Epoch 66/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2544 - acc: 0.9137 - val_loss: 0.1947 - val_acc: 0.9244
# Epoch 67/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2616 - acc: 0.9126 - val_loss: 0.1777 - val_acc: 0.9201
# Epoch 68/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2697 - acc: 0.9185 - val_loss: 0.1687 - val_acc: 0.9258
# Epoch 69/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2595 - acc: 0.9163 - val_loss: 0.1741 - val_acc: 0.9258
# Epoch 70/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2453 - acc: 0.9167 - val_loss: 0.1805 - val_acc: 0.9387
# Epoch 71/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2904 - acc: 0.9126 - val_loss: 0.1770 - val_acc: 0.9387
# Epoch 72/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2643 - acc: 0.9155 - val_loss: 0.1722 - val_acc: 0.9415
# Epoch 73/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2665 - acc: 0.9200 - val_loss: 0.1697 - val_acc: 0.9358
# Epoch 74/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2568 - acc: 0.9159 - val_loss: 0.1683 - val_acc: 0.9429
# Epoch 75/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2530 - acc: 0.9241 - val_loss: 0.1829 - val_acc: 0.9515
# Epoch 76/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2768 - acc: 0.9155 - val_loss: 0.1607 - val_acc: 0.9358
# Epoch 77/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2550 - acc: 0.9241 - val_loss: 0.1661 - val_acc: 0.9358
# Epoch 78/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2606 - acc: 0.9159 - val_loss: 0.1606 - val_acc: 0.9458
# Epoch 79/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2696 - acc: 0.9200 - val_loss: 0.1718 - val_acc: 0.9472
# Epoch 80/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2494 - acc: 0.9268 - val_loss: 0.1607 - val_acc: 0.9415
# Epoch 81/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2694 - acc: 0.9133 - val_loss: 0.1570 - val_acc: 0.9472
# Epoch 82/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2557 - acc: 0.9159 - val_loss: 0.1635 - val_acc: 0.9458
# Epoch 83/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2564 - acc: 0.9200 - val_loss: 0.1746 - val_acc: 0.9415
# Epoch 84/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2317 - acc: 0.9230 - val_loss: 0.1728 - val_acc: 0.9515
# Epoch 85/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2734 - acc: 0.9148 - val_loss: 0.1636 - val_acc: 0.9458
# Epoch 86/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2458 - acc: 0.9249 - val_loss: 0.1706 - val_acc: 0.9387
# Epoch 87/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2496 - acc: 0.9245 - val_loss: 0.1657 - val_acc: 0.9501
# Epoch 88/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2326 - acc: 0.9312 - val_loss: 0.1547 - val_acc: 0.9515
# Epoch 89/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2412 - acc: 0.9234 - val_loss: 0.1626 - val_acc: 0.9472
# Epoch 90/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2627 - acc: 0.9185 - val_loss: 0.1647 - val_acc: 0.9387
# Epoch 91/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2541 - acc: 0.9245 - val_loss: 0.1761 - val_acc: 0.9401
# Epoch 92/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2340 - acc: 0.9245 - val_loss: 0.1770 - val_acc: 0.9458
# Epoch 93/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2406 - acc: 0.9275 - val_loss: 0.1625 - val_acc: 0.9458
# Epoch 94/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2361 - acc: 0.9249 - val_loss: 0.1613 - val_acc: 0.9472
# Epoch 95/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2414 - acc: 0.9230 - val_loss: 0.1650 - val_acc: 0.9458
# Epoch 96/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2543 - acc: 0.9212 - val_loss: 0.1586 - val_acc: 0.9444
# Epoch 97/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2304 - acc: 0.9271 - val_loss: 0.1682 - val_acc: 0.9415
# Epoch 98/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2491 - acc: 0.9260 - val_loss: 0.1594 - val_acc: 0.9401
# Epoch 99/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2258 - acc: 0.9312 - val_loss: 0.1601 - val_acc: 0.9444
# Epoch 100/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2522 - acc: 0.9226 - val_loss: 0.1648 - val_acc: 0.9458
# Epoch 101/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2418 - acc: 0.9339 - val_loss: 0.1568 - val_acc: 0.9387
# Epoch 102/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2436 - acc: 0.9260 - val_loss: 0.1554 - val_acc: 0.9458
# Epoch 103/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2430 - acc: 0.9226 - val_loss: 0.1568 - val_acc: 0.9501
# Epoch 104/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2390 - acc: 0.9260 - val_loss: 0.1582 - val_acc: 0.9486
# Epoch 105/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2309 - acc: 0.9264 - val_loss: 0.1571 - val_acc: 0.9486
# Epoch 106/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2372 - acc: 0.9268 - val_loss: 0.1558 - val_acc: 0.9486
# Epoch 107/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2386 - acc: 0.9275 - val_loss: 0.1513 - val_acc: 0.9472
# Epoch 108/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2357 - acc: 0.9283 - val_loss: 0.1483 - val_acc: 0.9444
# Epoch 109/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2313 - acc: 0.9309 - val_loss: 0.1522 - val_acc: 0.9444
# Epoch 110/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2425 - acc: 0.9264 - val_loss: 0.1635 - val_acc: 0.9558
# Epoch 111/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2345 - acc: 0.9312 - val_loss: 0.1557 - val_acc: 0.9415
# Epoch 112/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2492 - acc: 0.9283 - val_loss: 0.1610 - val_acc: 0.9515
# Epoch 113/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2329 - acc: 0.9279 - val_loss: 0.1632 - val_acc: 0.9429
# Epoch 114/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2258 - acc: 0.9350 - val_loss: 0.1553 - val_acc: 0.9458
# Epoch 115/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2387 - acc: 0.9271 - val_loss: 0.1566 - val_acc: 0.9501
# Epoch 116/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2252 - acc: 0.9316 - val_loss: 0.1580 - val_acc: 0.9458
# Epoch 117/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2180 - acc: 0.9275 - val_loss: 0.1547 - val_acc: 0.9472
# Epoch 118/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2347 - acc: 0.9339 - val_loss: 0.1494 - val_acc: 0.9501
# Epoch 119/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2340 - acc: 0.9357 - val_loss: 0.1498 - val_acc: 0.9486
# Epoch 120/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2465 - acc: 0.9283 - val_loss: 0.1507 - val_acc: 0.9486
# Epoch 121/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2355 - acc: 0.9297 - val_loss: 0.1538 - val_acc: 0.9515
# Epoch 122/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2547 - acc: 0.9320 - val_loss: 0.1481 - val_acc: 0.9486
# Epoch 123/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2384 - acc: 0.9264 - val_loss: 0.1478 - val_acc: 0.9544
# Epoch 124/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2308 - acc: 0.9335 - val_loss: 0.1451 - val_acc: 0.9515
# Epoch 125/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.2450 - acc: 0.9309 - val_loss: 0.1489 - val_acc: 0.9501
# Epoch 126/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2378 - acc: 0.9264 - val_loss: 0.1444 - val_acc: 0.9515
# Epoch 127/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2119 - acc: 0.9324 - val_loss: 0.1548 - val_acc: 0.9515
# Epoch 128/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2210 - acc: 0.9309 - val_loss: 0.1563 - val_acc: 0.9529
# Epoch 129/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2244 - acc: 0.9346 - val_loss: 0.1546 - val_acc: 0.9486
# Epoch 130/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2179 - acc: 0.9316 - val_loss: 0.1609 - val_acc: 0.9515
# Epoch 131/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2354 - acc: 0.9327 - val_loss: 0.1471 - val_acc: 0.9472
# Epoch 132/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2329 - acc: 0.9297 - val_loss: 0.1422 - val_acc: 0.9501
# Epoch 133/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2313 - acc: 0.9312 - val_loss: 0.1483 - val_acc: 0.9544
# Epoch 134/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2376 - acc: 0.9320 - val_loss: 0.1448 - val_acc: 0.9444
# Epoch 135/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2214 - acc: 0.9346 - val_loss: 0.1460 - val_acc: 0.9515
# Epoch 136/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2341 - acc: 0.9260 - val_loss: 0.1427 - val_acc: 0.9544
# Epoch 137/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2091 - acc: 0.9387 - val_loss: 0.1539 - val_acc: 0.9558
# Epoch 138/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2245 - acc: 0.9294 - val_loss: 0.1468 - val_acc: 0.9515
# Epoch 139/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2266 - acc: 0.9365 - val_loss: 0.1451 - val_acc: 0.9472
# Epoch 140/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2184 - acc: 0.9346 - val_loss: 0.1429 - val_acc: 0.9572
# Epoch 141/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2239 - acc: 0.9316 - val_loss: 0.1507 - val_acc: 0.9501
# Epoch 142/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2235 - acc: 0.9383 - val_loss: 0.1507 - val_acc: 0.9515
# Epoch 143/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2118 - acc: 0.9331 - val_loss: 0.1400 - val_acc: 0.9529
# Epoch 144/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2039 - acc: 0.9436 - val_loss: 0.1444 - val_acc: 0.9486
# Epoch 145/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2276 - acc: 0.9361 - val_loss: 0.1539 - val_acc: 0.9486
# Epoch 146/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2162 - acc: 0.9327 - val_loss: 0.1532 - val_acc: 0.9515
# Epoch 147/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2226 - acc: 0.9324 - val_loss: 0.1431 - val_acc: 0.9529
# Epoch 148/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2225 - acc: 0.9357 - val_loss: 0.1458 - val_acc: 0.9501
# Epoch 149/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2321 - acc: 0.9335 - val_loss: 0.1436 - val_acc: 0.9486
# Epoch 150/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2304 - acc: 0.9320 - val_loss: 0.1587 - val_acc: 0.9429
# Epoch 151/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2062 - acc: 0.9331 - val_loss: 0.1524 - val_acc: 0.9501
# Epoch 152/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2243 - acc: 0.9324 - val_loss: 0.1504 - val_acc: 0.9515
# Epoch 153/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2261 - acc: 0.9271 - val_loss: 0.1562 - val_acc: 0.9501
# Epoch 154/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2226 - acc: 0.9339 - val_loss: 0.1554 - val_acc: 0.9529
# Epoch 155/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2298 - acc: 0.9335 - val_loss: 0.1440 - val_acc: 0.9472
# Epoch 156/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2183 - acc: 0.9365 - val_loss: 0.1459 - val_acc: 0.9486
# Epoch 157/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2115 - acc: 0.9339 - val_loss: 0.1456 - val_acc: 0.9486
# Epoch 158/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2459 - acc: 0.9372 - val_loss: 0.1417 - val_acc: 0.9501
# Epoch 159/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2116 - acc: 0.9406 - val_loss: 0.1402 - val_acc: 0.9501
# Epoch 160/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1975 - acc: 0.9417 - val_loss: 0.1428 - val_acc: 0.9529
# Epoch 161/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2289 - acc: 0.9324 - val_loss: 0.1443 - val_acc: 0.9529
# Epoch 162/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2300 - acc: 0.9339 - val_loss: 0.1436 - val_acc: 0.9501
# Epoch 163/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2209 - acc: 0.9406 - val_loss: 0.1412 - val_acc: 0.9529
# Epoch 164/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2009 - acc: 0.9428 - val_loss: 0.1430 - val_acc: 0.9529
# Epoch 165/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2000 - acc: 0.9398 - val_loss: 0.1382 - val_acc: 0.9558
# Epoch 166/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2112 - acc: 0.9365 - val_loss: 0.1481 - val_acc: 0.9486
# Epoch 167/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2445 - acc: 0.9316 - val_loss: 0.1450 - val_acc: 0.9529
# Epoch 168/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1996 - acc: 0.9428 - val_loss: 0.1519 - val_acc: 0.9515
# Epoch 169/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2309 - acc: 0.9376 - val_loss: 0.1484 - val_acc: 0.9558
# Epoch 170/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1903 - acc: 0.9413 - val_loss: 0.1668 - val_acc: 0.9544
# Epoch 171/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2134 - acc: 0.9380 - val_loss: 0.1563 - val_acc: 0.9515
# Epoch 172/500
# 2676/2676 [==============================] - 0s 36us/sample - loss: 0.2121 - acc: 0.9324 - val_loss: 0.1488 - val_acc: 0.9529
# Epoch 173/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2268 - acc: 0.9354 - val_loss: 0.1482 - val_acc: 0.9501
# Epoch 174/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2053 - acc: 0.9365 - val_loss: 0.1469 - val_acc: 0.9515
# Epoch 175/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2218 - acc: 0.9372 - val_loss: 0.1561 - val_acc: 0.9501
# Epoch 176/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1963 - acc: 0.9425 - val_loss: 0.1509 - val_acc: 0.9486
# Epoch 177/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2034 - acc: 0.9432 - val_loss: 0.1511 - val_acc: 0.9544
# Epoch 178/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2037 - acc: 0.9391 - val_loss: 0.1593 - val_acc: 0.9501
# Epoch 179/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2140 - acc: 0.9361 - val_loss: 0.1533 - val_acc: 0.9515
# Epoch 180/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2199 - acc: 0.9410 - val_loss: 0.1458 - val_acc: 0.9501
# Epoch 181/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2161 - acc: 0.9320 - val_loss: 0.1535 - val_acc: 0.9544
# Epoch 182/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2067 - acc: 0.9417 - val_loss: 0.1464 - val_acc: 0.9558
# Epoch 183/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2182 - acc: 0.9406 - val_loss: 0.1431 - val_acc: 0.9515
# Epoch 184/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2137 - acc: 0.9391 - val_loss: 0.1500 - val_acc: 0.9529
# Epoch 185/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2180 - acc: 0.9339 - val_loss: 0.1478 - val_acc: 0.9501
# Epoch 186/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2002 - acc: 0.9462 - val_loss: 0.1572 - val_acc: 0.9515
# Epoch 187/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1959 - acc: 0.9443 - val_loss: 0.1453 - val_acc: 0.9515
# Epoch 188/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1884 - acc: 0.9488 - val_loss: 0.1469 - val_acc: 0.9515
# Epoch 189/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2208 - acc: 0.9361 - val_loss: 0.1453 - val_acc: 0.9501
# Epoch 190/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2076 - acc: 0.9380 - val_loss: 0.1449 - val_acc: 0.9529
# Epoch 191/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1990 - acc: 0.9402 - val_loss: 0.1414 - val_acc: 0.9529
# Epoch 192/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2029 - acc: 0.9425 - val_loss: 0.1472 - val_acc: 0.9529
# Epoch 193/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2003 - acc: 0.9402 - val_loss: 0.1462 - val_acc: 0.9515
# Epoch 194/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2006 - acc: 0.9425 - val_loss: 0.1457 - val_acc: 0.9529
# Epoch 195/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2033 - acc: 0.9417 - val_loss: 0.1531 - val_acc: 0.9515
# Epoch 196/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2236 - acc: 0.9387 - val_loss: 0.1580 - val_acc: 0.9529
# Epoch 197/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1808 - acc: 0.9436 - val_loss: 0.1633 - val_acc: 0.9544
# Epoch 198/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2135 - acc: 0.9361 - val_loss: 0.1682 - val_acc: 0.9486
# Epoch 199/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2058 - acc: 0.9380 - val_loss: 0.1468 - val_acc: 0.9544
# Epoch 200/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2229 - acc: 0.9365 - val_loss: 0.1508 - val_acc: 0.9515
# Epoch 201/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1930 - acc: 0.9466 - val_loss: 0.1408 - val_acc: 0.9486
# Epoch 202/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2157 - acc: 0.9361 - val_loss: 0.1385 - val_acc: 0.9529
# Epoch 203/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2076 - acc: 0.9398 - val_loss: 0.1433 - val_acc: 0.9572
# Epoch 204/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1876 - acc: 0.9454 - val_loss: 0.1481 - val_acc: 0.9544
# Epoch 205/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1991 - acc: 0.9368 - val_loss: 0.1477 - val_acc: 0.9515
# Epoch 206/500
# 2676/2676 [==============================] - 0s 36us/sample - loss: 0.2141 - acc: 0.9439 - val_loss: 0.1375 - val_acc: 0.9544
# Epoch 207/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2174 - acc: 0.9354 - val_loss: 0.1492 - val_acc: 0.9529
# Epoch 208/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.1935 - acc: 0.9458 - val_loss: 0.1457 - val_acc: 0.9544
# Epoch 209/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1823 - acc: 0.9469 - val_loss: 0.1445 - val_acc: 0.9586
# Epoch 210/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.1931 - acc: 0.9477 - val_loss: 0.1445 - val_acc: 0.9586
# Epoch 211/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1908 - acc: 0.9458 - val_loss: 0.1430 - val_acc: 0.9544
# Epoch 212/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1911 - acc: 0.9466 - val_loss: 0.1406 - val_acc: 0.9515
# Epoch 213/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2216 - acc: 0.9354 - val_loss: 0.1438 - val_acc: 0.9515
# Epoch 214/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2017 - acc: 0.9432 - val_loss: 0.1419 - val_acc: 0.9544
# Epoch 215/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1974 - acc: 0.9432 - val_loss: 0.1470 - val_acc: 0.9501
# Epoch 216/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1792 - acc: 0.9473 - val_loss: 0.1556 - val_acc: 0.9515
# Epoch 217/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2066 - acc: 0.9357 - val_loss: 0.1555 - val_acc: 0.9501
# Epoch 218/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1864 - acc: 0.9462 - val_loss: 0.1515 - val_acc: 0.9515
# Epoch 219/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2158 - acc: 0.9425 - val_loss: 0.1461 - val_acc: 0.9544
# Epoch 220/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1798 - acc: 0.9484 - val_loss: 0.1494 - val_acc: 0.9544
# Epoch 221/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1945 - acc: 0.9447 - val_loss: 0.1469 - val_acc: 0.9544
# Epoch 222/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1869 - acc: 0.9417 - val_loss: 0.1446 - val_acc: 0.9486
# Epoch 223/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1951 - acc: 0.9447 - val_loss: 0.1448 - val_acc: 0.9544
# Epoch 224/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2155 - acc: 0.9354 - val_loss: 0.1440 - val_acc: 0.9529
# Epoch 225/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2053 - acc: 0.9503 - val_loss: 0.1491 - val_acc: 0.9558
# Epoch 226/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1850 - acc: 0.9432 - val_loss: 0.1398 - val_acc: 0.9515
# Epoch 227/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2124 - acc: 0.9421 - val_loss: 0.1445 - val_acc: 0.9529
# Epoch 228/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1881 - acc: 0.9421 - val_loss: 0.1461 - val_acc: 0.9501
# Epoch 229/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.2017 - acc: 0.9402 - val_loss: 0.1479 - val_acc: 0.9486
# Epoch 230/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1959 - acc: 0.9421 - val_loss: 0.1608 - val_acc: 0.9501
# Epoch 231/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1960 - acc: 0.9439 - val_loss: 0.1556 - val_acc: 0.9558
# Epoch 232/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1972 - acc: 0.9428 - val_loss: 0.1553 - val_acc: 0.9515
# Epoch 233/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1972 - acc: 0.9443 - val_loss: 0.1544 - val_acc: 0.9515
# Epoch 234/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1666 - acc: 0.9514 - val_loss: 0.1541 - val_acc: 0.9529
# Epoch 235/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1800 - acc: 0.9507 - val_loss: 0.1563 - val_acc: 0.9501
# Epoch 236/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1892 - acc: 0.9428 - val_loss: 0.1559 - val_acc: 0.9515
# Epoch 237/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2028 - acc: 0.9432 - val_loss: 0.1478 - val_acc: 0.9529
# Epoch 238/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1876 - acc: 0.9473 - val_loss: 0.1523 - val_acc: 0.9515
# Epoch 239/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2035 - acc: 0.9421 - val_loss: 0.1452 - val_acc: 0.9515
# Epoch 240/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.1944 - acc: 0.9425 - val_loss: 0.1428 - val_acc: 0.9544
# Epoch 241/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2118 - acc: 0.9413 - val_loss: 0.1433 - val_acc: 0.9572
# Epoch 242/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1875 - acc: 0.9484 - val_loss: 0.1544 - val_acc: 0.9544
# Epoch 243/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1897 - acc: 0.9425 - val_loss: 0.1504 - val_acc: 0.9529
# Epoch 244/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2169 - acc: 0.9391 - val_loss: 0.1542 - val_acc: 0.9515
# Epoch 245/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1908 - acc: 0.9436 - val_loss: 0.1664 - val_acc: 0.9515
# Epoch 246/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1960 - acc: 0.9439 - val_loss: 0.1525 - val_acc: 0.9529
# Epoch 247/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1708 - acc: 0.9484 - val_loss: 0.1555 - val_acc: 0.9544
# Epoch 248/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1963 - acc: 0.9484 - val_loss: 0.1502 - val_acc: 0.9529
# Epoch 249/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2053 - acc: 0.9417 - val_loss: 0.1501 - val_acc: 0.9529
# Epoch 250/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1747 - acc: 0.9473 - val_loss: 0.1550 - val_acc: 0.9558
# Epoch 251/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1927 - acc: 0.9443 - val_loss: 0.1541 - val_acc: 0.9501
# Epoch 252/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1849 - acc: 0.9462 - val_loss: 0.1549 - val_acc: 0.9558
# Epoch 253/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1941 - acc: 0.9488 - val_loss: 0.1492 - val_acc: 0.9529
# Epoch 254/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1943 - acc: 0.9425 - val_loss: 0.1490 - val_acc: 0.9544
# Epoch 255/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2187 - acc: 0.9428 - val_loss: 0.1514 - val_acc: 0.9501
# Epoch 256/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1978 - acc: 0.9410 - val_loss: 0.1389 - val_acc: 0.9515
# Epoch 257/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1915 - acc: 0.9410 - val_loss: 0.1398 - val_acc: 0.9558
# Epoch 258/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1810 - acc: 0.9488 - val_loss: 0.1446 - val_acc: 0.9515
# Epoch 259/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1814 - acc: 0.9454 - val_loss: 0.1414 - val_acc: 0.9501
# Epoch 260/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1885 - acc: 0.9466 - val_loss: 0.1468 - val_acc: 0.9544
# Epoch 261/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1833 - acc: 0.9428 - val_loss: 0.1565 - val_acc: 0.9486
# Epoch 262/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1733 - acc: 0.9481 - val_loss: 0.1536 - val_acc: 0.9572
# Epoch 263/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1962 - acc: 0.9417 - val_loss: 0.1470 - val_acc: 0.9515
# Epoch 264/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1773 - acc: 0.9436 - val_loss: 0.1462 - val_acc: 0.9544
# Epoch 265/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1928 - acc: 0.9481 - val_loss: 0.1516 - val_acc: 0.9544
# Epoch 266/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1925 - acc: 0.9447 - val_loss: 0.1537 - val_acc: 0.9515
# Epoch 267/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1977 - acc: 0.9372 - val_loss: 0.1563 - val_acc: 0.9558
# Epoch 268/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2053 - acc: 0.9439 - val_loss: 0.1479 - val_acc: 0.9529
# Epoch 269/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.2012 - acc: 0.9425 - val_loss: 0.1466 - val_acc: 0.9558
# Epoch 270/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1842 - acc: 0.9473 - val_loss: 0.1491 - val_acc: 0.9572
# Epoch 271/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.2024 - acc: 0.9425 - val_loss: 0.1516 - val_acc: 0.9544
# Epoch 272/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2071 - acc: 0.9473 - val_loss: 0.1441 - val_acc: 0.9586
# Epoch 273/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1925 - acc: 0.9436 - val_loss: 0.1474 - val_acc: 0.9529
# Epoch 274/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1881 - acc: 0.9507 - val_loss: 0.1462 - val_acc: 0.9544
# Epoch 275/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1820 - acc: 0.9458 - val_loss: 0.1500 - val_acc: 0.9544
# Epoch 276/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1892 - acc: 0.9477 - val_loss: 0.1432 - val_acc: 0.9572
# Epoch 277/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1956 - acc: 0.9387 - val_loss: 0.1496 - val_acc: 0.9529
# Epoch 278/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.1689 - acc: 0.9507 - val_loss: 0.1636 - val_acc: 0.9558
# Epoch 279/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2001 - acc: 0.9417 - val_loss: 0.1448 - val_acc: 0.9544
# Epoch 280/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1750 - acc: 0.9496 - val_loss: 0.1530 - val_acc: 0.9544
# Epoch 281/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.2011 - acc: 0.9391 - val_loss: 0.1454 - val_acc: 0.9501
# Epoch 282/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1764 - acc: 0.9462 - val_loss: 0.1771 - val_acc: 0.9501
# Epoch 283/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1950 - acc: 0.9406 - val_loss: 0.1586 - val_acc: 0.9544
# Epoch 284/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.1985 - acc: 0.9443 - val_loss: 0.1640 - val_acc: 0.9501
# Epoch 285/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1779 - acc: 0.9496 - val_loss: 0.1640 - val_acc: 0.9544
# Epoch 286/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1965 - acc: 0.9421 - val_loss: 0.1439 - val_acc: 0.9529
# Epoch 287/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1822 - acc: 0.9469 - val_loss: 0.1504 - val_acc: 0.9529
# Epoch 288/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1840 - acc: 0.9443 - val_loss: 0.1541 - val_acc: 0.9558
# Epoch 289/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2162 - acc: 0.9391 - val_loss: 0.1533 - val_acc: 0.9529
# Epoch 290/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1942 - acc: 0.9451 - val_loss: 0.1490 - val_acc: 0.9586
# Epoch 291/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1932 - acc: 0.9432 - val_loss: 0.1490 - val_acc: 0.9544
# Epoch 292/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1861 - acc: 0.9432 - val_loss: 0.1709 - val_acc: 0.9515
# Epoch 293/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1719 - acc: 0.9488 - val_loss: 0.1677 - val_acc: 0.9529
# Epoch 294/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1844 - acc: 0.9488 - val_loss: 0.1517 - val_acc: 0.9558
# Epoch 295/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1888 - acc: 0.9473 - val_loss: 0.1507 - val_acc: 0.9558
# Epoch 296/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.1835 - acc: 0.9432 - val_loss: 0.1524 - val_acc: 0.9586
# Epoch 297/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1780 - acc: 0.9481 - val_loss: 0.1495 - val_acc: 0.9572
# Epoch 298/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1904 - acc: 0.9421 - val_loss: 0.1439 - val_acc: 0.9572
# Epoch 299/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1916 - acc: 0.9462 - val_loss: 0.1606 - val_acc: 0.9558
# Epoch 300/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1804 - acc: 0.9458 - val_loss: 0.1470 - val_acc: 0.9515
# Epoch 301/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1648 - acc: 0.9458 - val_loss: 0.1593 - val_acc: 0.9558
# Epoch 302/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.2089 - acc: 0.9368 - val_loss: 0.1480 - val_acc: 0.9586
# Epoch 303/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.1745 - acc: 0.9481 - val_loss: 0.1477 - val_acc: 0.9558
# Epoch 304/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1716 - acc: 0.9469 - val_loss: 0.1557 - val_acc: 0.9529
# Epoch 305/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.1906 - acc: 0.9466 - val_loss: 0.1571 - val_acc: 0.9529
# Epoch 306/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1779 - acc: 0.9458 - val_loss: 0.1592 - val_acc: 0.9586
# Epoch 307/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1790 - acc: 0.9533 - val_loss: 0.1415 - val_acc: 0.9544
# Epoch 308/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1617 - acc: 0.9529 - val_loss: 0.1567 - val_acc: 0.9572
# Epoch 309/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1950 - acc: 0.9451 - val_loss: 0.1576 - val_acc: 0.9572
# Epoch 310/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1963 - acc: 0.9462 - val_loss: 0.1446 - val_acc: 0.9558
# Epoch 311/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1768 - acc: 0.9466 - val_loss: 0.1512 - val_acc: 0.9558
# Epoch 312/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1909 - acc: 0.9447 - val_loss: 0.1501 - val_acc: 0.9544
# Epoch 313/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1707 - acc: 0.9540 - val_loss: 0.1560 - val_acc: 0.9572
# Epoch 314/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1770 - acc: 0.9499 - val_loss: 0.1598 - val_acc: 0.9544
# Epoch 315/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1790 - acc: 0.9529 - val_loss: 0.1471 - val_acc: 0.9515
# Epoch 316/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1932 - acc: 0.9421 - val_loss: 0.1459 - val_acc: 0.9544
# Epoch 317/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1844 - acc: 0.9518 - val_loss: 0.1481 - val_acc: 0.9529
# Epoch 318/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1710 - acc: 0.9510 - val_loss: 0.1490 - val_acc: 0.9515
# Epoch 319/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1847 - acc: 0.9522 - val_loss: 0.1451 - val_acc: 0.9515
# Epoch 320/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1567 - acc: 0.9525 - val_loss: 0.1540 - val_acc: 0.9572
# Epoch 321/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1804 - acc: 0.9499 - val_loss: 0.1463 - val_acc: 0.9544
# Epoch 322/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1885 - acc: 0.9477 - val_loss: 0.1579 - val_acc: 0.9601
# Epoch 323/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.1533 - acc: 0.9593 - val_loss: 0.1505 - val_acc: 0.9572
# Epoch 324/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1833 - acc: 0.9477 - val_loss: 0.1360 - val_acc: 0.9558
# Epoch 325/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1837 - acc: 0.9529 - val_loss: 0.1412 - val_acc: 0.9558
# Epoch 326/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1559 - acc: 0.9552 - val_loss: 0.1483 - val_acc: 0.9529
# Epoch 327/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1901 - acc: 0.9428 - val_loss: 0.1412 - val_acc: 0.9544
# Epoch 328/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1677 - acc: 0.9525 - val_loss: 0.1411 - val_acc: 0.9529
# Epoch 329/500
# 2676/2676 [==============================] - 0s 44us/sample - loss: 0.1883 - acc: 0.9484 - val_loss: 0.1583 - val_acc: 0.9544
# Epoch 330/500
# 2676/2676 [==============================] - 0s 43us/sample - loss: 0.1864 - acc: 0.9496 - val_loss: 0.1471 - val_acc: 0.9572
# Epoch 331/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1850 - acc: 0.9451 - val_loss: 0.1578 - val_acc: 0.9572
# Epoch 332/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1581 - acc: 0.9540 - val_loss: 0.1558 - val_acc: 0.9586
# Epoch 333/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1665 - acc: 0.9507 - val_loss: 0.1603 - val_acc: 0.9572
# Epoch 334/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1727 - acc: 0.9518 - val_loss: 0.1484 - val_acc: 0.9601
# Epoch 335/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1664 - acc: 0.9570 - val_loss: 0.1463 - val_acc: 0.9558
# Epoch 336/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1790 - acc: 0.9488 - val_loss: 0.1585 - val_acc: 0.9544
# Epoch 337/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1745 - acc: 0.9469 - val_loss: 0.1469 - val_acc: 0.9572
# Epoch 338/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1942 - acc: 0.9488 - val_loss: 0.1582 - val_acc: 0.9558
# Epoch 339/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1806 - acc: 0.9499 - val_loss: 0.1570 - val_acc: 0.9572
# Epoch 340/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1594 - acc: 0.9529 - val_loss: 0.1549 - val_acc: 0.9572
# Epoch 341/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1739 - acc: 0.9537 - val_loss: 0.1621 - val_acc: 0.9558
# Epoch 342/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1937 - acc: 0.9469 - val_loss: 0.1574 - val_acc: 0.9529
# Epoch 343/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1757 - acc: 0.9484 - val_loss: 0.1484 - val_acc: 0.9558
# Epoch 344/500
# ...
# Epoch 387/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1747 - acc: 0.9525 - val_loss: 0.1517 - val_acc: 0.9572
# Epoch 388/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1826 - acc: 0.9477 - val_loss: 0.1519 - val_acc: 0.9558
# Epoch 389/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.1654 - acc: 0.9544 - val_loss: 0.1474 - val_acc: 0.9529
# Epoch 390/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1497 - acc: 0.9525 - val_loss: 0.1502 - val_acc: 0.9544
# Epoch 391/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1846 - acc: 0.9507 - val_loss: 0.1660 - val_acc: 0.9572
# Epoch 392/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1613 - acc: 0.9548 - val_loss: 0.1663 - val_acc: 0.9544
# Epoch 393/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1563 - acc: 0.9559 - val_loss: 0.1617 - val_acc: 0.9558
# Epoch 394/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1572 - acc: 0.9525 - val_loss: 0.1593 - val_acc: 0.9572
# Epoch 395/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1450 - acc: 0.9596 - val_loss: 0.1660 - val_acc: 0.9572
# Epoch 396/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1764 - acc: 0.9559 - val_loss: 0.1609 - val_acc: 0.9544
# Epoch 397/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1845 - acc: 0.9473 - val_loss: 0.1548 - val_acc: 0.9586
# Epoch 398/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1670 - acc: 0.9529 - val_loss: 0.1555 - val_acc: 0.9529
# Epoch 399/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1762 - acc: 0.9488 - val_loss: 0.1464 - val_acc: 0.9586
# Epoch 400/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1668 - acc: 0.9548 - val_loss: 0.1645 - val_acc: 0.9586
# Epoch 401/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1724 - acc: 0.9522 - val_loss: 0.1566 - val_acc: 0.9572
# Epoch 402/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1709 - acc: 0.9525 - val_loss: 0.1446 - val_acc: 0.9544
# Epoch 403/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1495 - acc: 0.9559 - val_loss: 0.1679 - val_acc: 0.9544
# Epoch 404/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1626 - acc: 0.9581 - val_loss: 0.1520 - val_acc: 0.9572
# Epoch 405/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1786 - acc: 0.9510 - val_loss: 0.1472 - val_acc: 0.9601
# Epoch 406/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1663 - acc: 0.9522 - val_loss: 0.1606 - val_acc: 0.9572
# Epoch 407/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1696 - acc: 0.9544 - val_loss: 0.1505 - val_acc: 0.9558
# Epoch 408/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1757 - acc: 0.9514 - val_loss: 0.1486 - val_acc: 0.9558
# Epoch 409/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1643 - acc: 0.9507 - val_loss: 0.1531 - val_acc: 0.9572
# Epoch 410/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1719 - acc: 0.9514 - val_loss: 0.1587 - val_acc: 0.9601
# Epoch 411/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1675 - acc: 0.9525 - val_loss: 0.1593 - val_acc: 0.9572
# Epoch 412/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1647 - acc: 0.9540 - val_loss: 0.1550 - val_acc: 0.9586
# Epoch 413/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1558 - acc: 0.9552 - val_loss: 0.1592 - val_acc: 0.9586
# Epoch 414/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1813 - acc: 0.9540 - val_loss: 0.1481 - val_acc: 0.9586
# Epoch 415/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1760 - acc: 0.9488 - val_loss: 0.1442 - val_acc: 0.9601
# Epoch 416/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1669 - acc: 0.9533 - val_loss: 0.1503 - val_acc: 0.9586
# Epoch 417/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1667 - acc: 0.9540 - val_loss: 0.1641 - val_acc: 0.9586
# Epoch 418/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1506 - acc: 0.9548 - val_loss: 0.1582 - val_acc: 0.9572
# Epoch 419/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1652 - acc: 0.9533 - val_loss: 0.1541 - val_acc: 0.9572
# Epoch 420/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1622 - acc: 0.9559 - val_loss: 0.1526 - val_acc: 0.9572
# Epoch 421/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1728 - acc: 0.9522 - val_loss: 0.1400 - val_acc: 0.9529
# Epoch 422/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1762 - acc: 0.9503 - val_loss: 0.1446 - val_acc: 0.9601
# Epoch 423/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1570 - acc: 0.9525 - val_loss: 0.1460 - val_acc: 0.9572
# Epoch 424/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1514 - acc: 0.9570 - val_loss: 0.1477 - val_acc: 0.9586
# Epoch 425/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1534 - acc: 0.9593 - val_loss: 0.1728 - val_acc: 0.9558
# Epoch 426/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1669 - acc: 0.9544 - val_loss: 0.1605 - val_acc: 0.9572
# Epoch 427/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1586 - acc: 0.9525 - val_loss: 0.1718 - val_acc: 0.9572
# Epoch 428/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1733 - acc: 0.9559 - val_loss: 0.1534 - val_acc: 0.9586
# Epoch 429/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1617 - acc: 0.9589 - val_loss: 0.1473 - val_acc: 0.9572
# Epoch 430/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1615 - acc: 0.9555 - val_loss: 0.1575 - val_acc: 0.9558
# Epoch 431/500
# 2676/2676 [==============================] - 0s 42us/sample - loss: 0.1628 - acc: 0.9555 - val_loss: 0.1586 - val_acc: 0.9572
# Epoch 432/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1603 - acc: 0.9537 - val_loss: 0.1622 - val_acc: 0.9572
# Epoch 433/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1595 - acc: 0.9589 - val_loss: 0.1658 - val_acc: 0.9601
# Epoch 434/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1729 - acc: 0.9499 - val_loss: 0.1720 - val_acc: 0.9615
# Epoch 435/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1710 - acc: 0.9507 - val_loss: 0.1537 - val_acc: 0.9586
# Epoch 436/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1644 - acc: 0.9548 - val_loss: 0.1585 - val_acc: 0.9586
# Epoch 437/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1635 - acc: 0.9585 - val_loss: 0.1558 - val_acc: 0.9572
# Epoch 438/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1624 - acc: 0.9533 - val_loss: 0.1564 - val_acc: 0.9601
# Epoch 439/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1324 - acc: 0.9615 - val_loss: 0.1688 - val_acc: 0.9601
# Epoch 440/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1510 - acc: 0.9593 - val_loss: 0.1624 - val_acc: 0.9558
# Epoch 441/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1566 - acc: 0.9567 - val_loss: 0.1494 - val_acc: 0.9558
# Epoch 442/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1795 - acc: 0.9522 - val_loss: 0.1480 - val_acc: 0.9586
# Epoch 443/500
# 2676/2676 [==============================] - 0s 37us/sample - loss: 0.1610 - acc: 0.9533 - val_loss: 0.1504 - val_acc: 0.9572
# Epoch 444/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1567 - acc: 0.9570 - val_loss: 0.1640 - val_acc: 0.9586
# Epoch 445/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1584 - acc: 0.9548 - val_loss: 0.1626 - val_acc: 0.9586
# Epoch 446/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1350 - acc: 0.9615 - val_loss: 0.1626 - val_acc: 0.9601
# Epoch 447/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1462 - acc: 0.9570 - val_loss: 0.1496 - val_acc: 0.9572
# Epoch 448/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1848 - acc: 0.9477 - val_loss: 0.1508 - val_acc: 0.9558
# Epoch 449/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1756 - acc: 0.9522 - val_loss: 0.1474 - val_acc: 0.9586
# Epoch 450/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1676 - acc: 0.9510 - val_loss: 0.1494 - val_acc: 0.9572
# Epoch 451/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1653 - acc: 0.9563 - val_loss: 0.1454 - val_acc: 0.9586
# Epoch 452/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1642 - acc: 0.9570 - val_loss: 0.1529 - val_acc: 0.9615
# Epoch 453/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1490 - acc: 0.9623 - val_loss: 0.1503 - val_acc: 0.9586
# Epoch 454/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1630 - acc: 0.9559 - val_loss: 0.1440 - val_acc: 0.9586
# Epoch 455/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1746 - acc: 0.9552 - val_loss: 0.1517 - val_acc: 0.9643
# Epoch 456/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1500 - acc: 0.9555 - val_loss: 0.1628 - val_acc: 0.9615
# Epoch 457/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1402 - acc: 0.9634 - val_loss: 0.1672 - val_acc: 0.9586
# Epoch 458/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1765 - acc: 0.9548 - val_loss: 0.1502 - val_acc: 0.9601
# Epoch 459/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1733 - acc: 0.9510 - val_loss: 0.1494 - val_acc: 0.9601
# Epoch 460/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1539 - acc: 0.9555 - val_loss: 0.1667 - val_acc: 0.9615
# Epoch 461/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1693 - acc: 0.9522 - val_loss: 0.1603 - val_acc: 0.9586
# Epoch 462/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1522 - acc: 0.9589 - val_loss: 0.1562 - val_acc: 0.9601
# Epoch 463/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1555 - acc: 0.9581 - val_loss: 0.1625 - val_acc: 0.9601
# Epoch 464/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1477 - acc: 0.9581 - val_loss: 0.1613 - val_acc: 0.9586
# Epoch 465/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1485 - acc: 0.9604 - val_loss: 0.1474 - val_acc: 0.9601
# Epoch 466/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1554 - acc: 0.9548 - val_loss: 0.1495 - val_acc: 0.9629
# Epoch 467/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1660 - acc: 0.9537 - val_loss: 0.1499 - val_acc: 0.9544
# Epoch 468/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1524 - acc: 0.9559 - val_loss: 0.1554 - val_acc: 0.9601
# Epoch 469/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1543 - acc: 0.9537 - val_loss: 0.1671 - val_acc: 0.9601
# Epoch 470/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1470 - acc: 0.9589 - val_loss: 0.1661 - val_acc: 0.9586
# Epoch 471/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1542 - acc: 0.9604 - val_loss: 0.1613 - val_acc: 0.9586
# Epoch 472/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1599 - acc: 0.9593 - val_loss: 0.1489 - val_acc: 0.9615
# Epoch 473/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1637 - acc: 0.9518 - val_loss: 0.1601 - val_acc: 0.9586
# Epoch 474/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1420 - acc: 0.9574 - val_loss: 0.1727 - val_acc: 0.9615
# Epoch 475/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1463 - acc: 0.9611 - val_loss: 0.1592 - val_acc: 0.9643
# Epoch 476/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1600 - acc: 0.9544 - val_loss: 0.1695 - val_acc: 0.9615
# Epoch 477/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1362 - acc: 0.9634 - val_loss: 0.1736 - val_acc: 0.9601
# Epoch 478/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1364 - acc: 0.9608 - val_loss: 0.1679 - val_acc: 0.9658
# Epoch 479/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1651 - acc: 0.9555 - val_loss: 0.1492 - val_acc: 0.9572
# Epoch 480/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1451 - acc: 0.9641 - val_loss: 0.1438 - val_acc: 0.9615
# Epoch 481/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1652 - acc: 0.9552 - val_loss: 0.1574 - val_acc: 0.9615
# Epoch 482/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1430 - acc: 0.9604 - val_loss: 0.1545 - val_acc: 0.9601
# Epoch 483/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1626 - acc: 0.9529 - val_loss: 0.1508 - val_acc: 0.9601
# Epoch 484/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1696 - acc: 0.9567 - val_loss: 0.1442 - val_acc: 0.9586
# Epoch 485/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1494 - acc: 0.9563 - val_loss: 0.1506 - val_acc: 0.9601
# Epoch 486/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1583 - acc: 0.9555 - val_loss: 0.1563 - val_acc: 0.9601
# Epoch 487/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1694 - acc: 0.9537 - val_loss: 0.1478 - val_acc: 0.9586
# Epoch 488/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1638 - acc: 0.9589 - val_loss: 0.1477 - val_acc: 0.9586
# Epoch 489/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1373 - acc: 0.9649 - val_loss: 0.1665 - val_acc: 0.9586
# Epoch 490/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1533 - acc: 0.9608 - val_loss: 0.1530 - val_acc: 0.9586
# Epoch 491/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1437 - acc: 0.9593 - val_loss: 0.1598 - val_acc: 0.9572
# Epoch 492/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1684 - acc: 0.9522 - val_loss: 0.1416 - val_acc: 0.9629
# Epoch 493/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1659 - acc: 0.9559 - val_loss: 0.1366 - val_acc: 0.9629
# Epoch 494/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1601 - acc: 0.9559 - val_loss: 0.1503 - val_acc: 0.9643
# Epoch 495/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1337 - acc: 0.9638 - val_loss: 0.1471 - val_acc: 0.9629
# Epoch 496/500
# 2676/2676 [==============================] - 0s 41us/sample - loss: 0.1731 - acc: 0.9585 - val_loss: 0.1528 - val_acc: 0.9658
# Epoch 497/500
# 2676/2676 [==============================] - 0s 39us/sample - loss: 0.1547 - acc: 0.9604 - val_loss: 0.1475 - val_acc: 0.9601
# Epoch 498/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1390 - acc: 0.9608 - val_loss: 0.1615 - val_acc: 0.9586
# Epoch 499/500
# 2676/2676 [==============================] - 0s 40us/sample - loss: 0.1481 - acc: 0.9574 - val_loss: 0.1486 - val_acc: 0.9572
# Epoch 500/500
# 2676/2676 [==============================] - 0s 38us/sample - loss: 0.1717 - acc: 0.9589 - val_loss: 0.1399 - val_acc: 0.9629

# %%
plot_history(history)

# %%
# save model 
model.save('pose_classifier.h5')

# %%
# Testing on single example
LABELS = ["STANDING", "BENDING", "CROUCHING"]

X_sample = load_X('dataset/X_sample.txt')
X_sample_norm = norm_X(X_sample)
y_out = model.predict(X_sample_norm[0].reshape(1, 36))

print("Estimated pose:")
for idx in range(len(LABELS)):
    print(LABELS[idx] + ": \t" + str(y_out[0][idx]))
plot(X_sample[0])
# Out:
# Estimated pose:
# STANDING: 	0.05383162
# BENDING: 	0.013991522
# CROUCHING: 	0.9321768

# %%
X_sample[0]
# Out:
# array([ 533.882  ,  388.70547,  544.8678 ,  526.60767,  425.08575,
#         512.1124 ,  417.78983,  740.82495,  385.09637,  664.53375,
#         660.9374 ,  533.8324 ,  635.50964,  795.03125,  454.12094,
#         831.36127,  497.63477,  867.6868 ,  250.93797,  835.04785,
#         432.3186 , 1092.6522 ,  653.5648 ,  900.40186,  363.2616 ,
#         893.10504,  621.06165, 1081.7125 ,  508.40002,  348.8913 ,
#         566.73413,  363.1943 ,  475.6909 ,  359.54095,  610.0567 ,
#         385.11093], dtype=float32)

# %%
X_sample_norm[0]
# Out:
# array([ 0.02696206, -0.24112062,  0.03626795, -0.12430575, -0.06519762,
#        -0.13658445, -0.07137789,  0.0571545 , -0.09907202, -0.00747063,
#         0.13458875, -0.11818579,  0.1130493 ,  0.10307184, -0.04060235,
#         0.13384645, -0.00374244,  0.16461729, -0.21271559,  0.1369693 ,
#        -0.05907078,  0.3551821 ,  0.12834357,  0.1923297 , -0.11756794,
#         0.18614868,  0.10081062,  0.34591525,  0.00537665, -0.27484662,
#         0.05479059, -0.26273075, -0.02233077, -0.26582545,  0.09148849,
#        -0.24416551])

# %%
X_train.shape
# Out:
# (2676, 36)

# %%
X_train_norm
# Out:
# array([[-0.06378927, -0.32805909,  0.04035647, ..., -0.        ,
#          0.02647038, -0.30028689],
#        [-0.16565792, -0.24813442,  0.01409855, ..., -0.32215179,
#         -0.10221446, -0.27985615],
#        [-0.1786875 , -0.25772235,  0.01718149, ..., -0.31957571,
#         -0.09621634, -0.26803124],
#        ...,
#        [ 0.09145509, -0.20297831, -0.04005403, ..., -0.2595356 ,
#         -0.        , -0.        ],
#        [-0.09871121, -0.16568105,  0.09543595, ..., -0.        ,
#         -0.02479915, -0.31357428],
#        [-0.18946615, -0.18003524,  0.02389214, ..., -0.        ,
#         -0.10412145, -0.29637347]])

# %% [markdown]
# ## Load Alpha Pose

# %%
index_alphapose={
    # Use 17 skeleton point
    "Nose": 0,
    #"Neck": "-",
    "RShoulder": 6,
    "RElbow": 8,
    "RWrist": 10,
    "LShoulder": 5,
    "LElbow": 7,
    "LWrist": 9,
    "RHip": 12,
    "RKnee": 14,
    "RAnkle": 16,
    "LHip": 11,
    "LKnee": 13,
    "LAnkle": 15,
    "REye": 2,
    "LEye": 1,
    "REar": 4,
    "LEar": 3
}

# %%
def find_neck_plot(alpha_example):
    
    x1= alpha_example[:,0] 
    y1= alpha_example[:,1]


    # 12 and 13 is x and y coordinate for right shoulder of alpha pose
    x2= alpha_example[:,2]
    y2= alpha_example[:,3]

    neck_= [float((x1 + x2)/2), float((y1 + y2)/2)]
    neck_=np.asarray(neck_)

    return neck_

def plot_line(a, b):
    if (a.any()> 0 and b.any()>0): plt.plot([a[0], b[0]], [a[1], b[1]], 'k-')
        
def plot_skeleton_alpha(sample, pattern):
    for i in range(len(sample)//2):
        plt.plot(sample[i*2], sample[i*2+1], pattern) 
    skeleton = sample.reshape(1, 34)
    Nose = skeleton[:,index_alphapose['Nose']*2:index_alphapose['Nose']*2+2][0]
    print("skeleton:",skeleton)

    Neck = find_neck_plot(skeleton)
    print("Neck:",Neck)

    RShoulder = skeleton[:,index_alphapose['RShoulder']*2:index_alphapose['RShoulder']*2+2][0]
    RElbow = skeleton[:,index_alphapose['RElbow']*2:index_alphapose['RElbow']*2+2][0]
    RWrist = skeleton[:,index_alphapose['RWrist']*2:index_alphapose['RWrist']*2+2][0]
    LShoulder = skeleton[:,index_alphapose['LShoulder']*2:index_alphapose['LShoulder']*2+2][0]
    LElbow = skeleton[:,index_alphapose['LElbow']*2:index_alphapose['LElbow']*2+2][0]
    LWrist = skeleton[:,index_alphapose['LWrist']*2:index_alphapose['LWrist']*2+2][0]
    RHip = skeleton[:,index_alphapose['RHip']*2:index_alphapose['RHip']*2+2][0]
    RKnee = skeleton[:,index_alphapose['RKnee']*2:index_alphapose['RKnee']*2+2][0]
    RAnkle = skeleton[:,index_alphapose['RAnkle']*2:index_alphapose['RAnkle']*2+2][0]
    LHip = skeleton[:,index_alphapose['LHip']*2:index_alphapose['LHip']*2+2][0]
    LKnee = skeleton[:,index_alphapose['LKnee']*2:index_alphapose['LKnee']*2+2][0]
    LAnkle = skeleton[:,index_alphapose['LAnkle']*2:index_alphapose['LAnkle']*2+2][0]
    REye = skeleton[:,index_alphapose['REye']*2:index_alphapose['REye']*2+2][0]
    LEye = skeleton[:,index_alphapose['LEye']*2:index_alphapose['LEye']*2+2][0]
    REar = skeleton[:,index_alphapose['REar']*2:index_alphapose['REar']*2+2][0]
    LEar = skeleton[:,index_alphapose['LEar']*2:index_alphapose['LEar']*2+2][0]
    #Nose = sample.reshape(1, 36)[:,0*2:0*2+2][0]
    #Neck = sample.reshape(1, 36)[:,1*2:1*2+2][0]
    plot_line(LEar, LEye)
    plot_line(LEye, Nose)
    plot_line(REar, REye)
    plot_line(REye, Nose)
    plot_line(Nose, Neck)
    plot_line(Neck, LShoulder)
    plot_line(LShoulder, LElbow)
    plot_line(LElbow, LWrist)
    plot_line(Neck, RShoulder)
    plot_line(RShoulder, RElbow)
    plot_line(RElbow, RWrist)
    plot_line(Neck, LHip)
    plot_line(LHip, LKnee)
    plot_line(LKnee, LAnkle)
    plot_line(Neck, RHip)
    plot_line(RHip, RKnee)
    plot_line(RKnee, RAnkle)
    
def plot_alpha(sample):
    # sample is one-dimension array
    # e.g: (34,)
    if sample.shape[0] == 34:
        sample_norm = norm_alpha(sample.reshape(1,34))[0]

        # Plot original coordinates
        pad_ori = 40
        plt.figure(str(sample))
        plt.subplot(121)
        plt.title('Original skeleton')
        X_ori = sample
        x_max = max(X_ori[0::2]) + pad_ori
        x_min = min(i for i in X_ori[0::2] if i > 0) - pad_ori
        y_max = max(X_ori[1::2]) + pad_ori
        y_min = min(j for j in X_ori[1::2] if j > 0) - pad_ori
        plt.xlim(x_min,x_max)
        plt.ylim(y_max, y_min)
        plot_skeleton_alpha(X_ori, 'bo')

        # Plot normalized coordinates
        pad_nor = 0.2
        #plt.figure(2)
        plt.subplot(122)
        plt.title('Normalized skeleton')
        X_nor = sample_norm
        x_max = max(X_nor[0::2]) + pad_nor
        x_min = min(X_nor[0::2]) - pad_nor
        y_max = max(X_nor[1::2]) + pad_nor
        y_min = min(X_nor[1::2]) - pad_nor
        plt.xlim(x_min,x_max)
        plt.ylim(y_max, y_min)
        plot_skeleton_alpha(X_nor, 'ro')
    else:
        print("sample is one-dimension array: (36,)")

# %%
import json 
import numpy as np
import torch

# Opening JSON file 
f = open('alphapose-results.json',) 
  
# returns JSON object as  
# a dictionary 
data = json.load(f) 
  

# Closing file 
f.close()

# %%
def data_converter(data):
    data=data['keypoints']
    keypoints=[]
    kp_score=[]
    for a in range (0,len(data)):
        score=[]
        if ((a+3)%3==0):
            keypoints.append(data[a])
            keypoints.append(data[a+1])
        elif((a+1)%3==0):
            score=[data[a]]
            kp_score.append(score)

    return keypoints

# %%
alpha_example=np.asarray(data_converter(data[150]))
alpha_example = np.append(alpha_example,data_converter(data[150]))
alpha_example = alpha_example.reshape(2, 34)

# %%
def euclidean_dist(a, b):
    # This function calculates the euclidean distance between 2 point in 2-D coordinates
    # if one of two points is (0,0), dist = 0
    # a, b: input array with dimension: m, 2
    # m: number of samples
    # 2: x and y coordinate
    try:
        if (a.shape[1] == 2 and a.shape == b.shape):
            # check if element of a and b is (0,0)
            bol_a = (a[:,0] != 0).astype(int)
            bol_b = (b[:,0] != 0).astype(int)
            dist = np.linalg.norm(a-b, axis=1)
            return((dist*bol_a*bol_b).reshape(a.shape[0],1))
    except:
        print("[Error]: Check dimension of input vector")
        return 0


# Function to find next in alpha pose because alpha pose did not have neck

def find_neck(alpha_example):
    
    # 10 and 11 is x and y coordinate for left shoulder of alpha pose
    x1= alpha_example[:,10] 
    y1= alpha_example[:,11]
    
    
    # 12 and 13 is x and y coordinate for right shoulder of alpha pose
    x2= alpha_example[:,12]
    y2= alpha_example[:,13]
    
    # Result will be  neck coordinate(array([586.35131836, 472.55082703]), array([559.9307251 , 480.63751221])) ((x1,x2),(y1,y2))
    neck_= ((x1 + x2)/2, (y1 + y2)/2)
    
    result_neck=[]
    for a,b in zip(neck_[0],neck_[1]):
        result_neck.append([a,b])
    
    neck=np.asarray(result_neck)
    return neck

def norm_alpha(X):
    num_sample = X.shape[0]
    # Keypoints
    Nose = X[:,index_alphapose['Nose']*2:index_alphapose['Nose']*2+2]
    Neck = find_neck(X)
    RShoulder = X[:,index_alphapose['RShoulder']*2:index_alphapose['RShoulder']*2+2]
    RElbow = X[:,index_alphapose['RElbow']*2:index_alphapose['RElbow']*2+2]
    RWrist = X[:,index_alphapose['RWrist']*2:index_alphapose['RWrist']*2+2]
    LShoulder = X[:,index_alphapose['LShoulder']*2:index_alphapose['LShoulder']*2+2]
    LElbow = X[:,index_alphapose['LElbow']*2:index_alphapose['LElbow']*2+2]
    LWrist = X[:,index_alphapose['LWrist']*2:index_alphapose['LWrist']*2+2]
    RHip = X[:,index_alphapose['RHip']*2:index_alphapose['RHip']*2+2]
    RKnee = X[:,index_alphapose['RKnee']*2:index_alphapose['RKnee']*2+2]
    RAnkle = X[:,index_alphapose['RAnkle']*2:index_alphapose['RAnkle']*2+2]
    LHip = X[:,index_alphapose['LHip']*2:index_alphapose['LHip']*2+2]
    LKnee = X[:,index_alphapose['LKnee']*2:index_alphapose['LKnee']*2+2]
    LAnkle = X[:,index_alphapose['LAnkle']*2:index_alphapose['LAnkle']*2+2]
    REye = X[:,index_alphapose['REye']*2:index_alphapose['REye']*2+2]
    LEye = X[:,index_alphapose['LEye']*2:index_alphapose['LEye']*2+2]
    REar = X[:,index_alphapose['REar']*2:index_alphapose['REar']*2+2]
    LEar = X[:,index_alphapose['LEar']*2:index_alphapose['LEar']*2+2]

    # Length of head
    length_Neck_LEar = euclidean_dist(Neck, LEar)
    length_Neck_REar = euclidean_dist(Neck, REar)
    length_Neck_LEye = euclidean_dist(Neck, LEye)
    length_Neck_REye = euclidean_dist(Neck, REye)
    length_Nose_LEar = euclidean_dist(Nose, LEar)
    length_Nose_REar = euclidean_dist(Nose, REar)
    length_Nose_LEye = euclidean_dist(Nose, LEye)
    length_Nose_REye = euclidean_dist(Nose, REye)
    length_head      = np.maximum.reduce([length_Neck_LEar, length_Neck_REar, length_Neck_LEye, length_Neck_REye, \
                                 length_Nose_LEar, length_Nose_REar, length_Nose_LEye, length_Nose_REye])
    #length_head      = np.sqrt(np.square((LEye[:,0:1]+REye[:,0:1])/2 - Neck[:,0:1]) + np.square((LEye[:,1:2]+REye[:,1:2])/2 - Neck[:,1:2]))

    # Length of torso
    length_Neck_LHip = euclidean_dist(Neck, LHip)
    length_Neck_RHip = euclidean_dist(Neck, RHip)
    length_torso     = np.maximum(length_Neck_LHip, length_Neck_RHip)
    #length_torso     = np.sqrt(np.square(Neck[:,0:1]-(LHip[:,0:1]+RHip[:,0:1])/2) + np.square(Neck[:,1:2]-(LHip[:,1:2]+RHip[:,1:2])/2))

    # Length of right leg
    length_leg_right = euclidean_dist(RHip, RKnee) + euclidean_dist(RKnee, RAnkle)
    #length_leg_right = np.sqrt(np.square(RHip[:,0:1]-RKnee[:,0:1]) + np.square(RHip[:,1:2]-RKnee[:,1:2])) \
    #+ np.sqrt(np.square(RKnee[:,0:1]-RAnkle[:,0:1]) + np.square(RKnee[:,1:2]-RAnkle[:,1:2]))

    # Length of left leg
    length_leg_left = euclidean_dist(LHip, LKnee) + euclidean_dist(LKnee, LAnkle)
    #length_leg_left = np.sqrt(np.square(LHip[:,0:1]-LKnee[:,0:1]) + np.square(LHip[:,1:2]-LKnee[:,1:2])) \
    #+ np.sqrt(np.square(LKnee[:,0:1]-LAnkle[:,0:1]) + np.square(LKnee[:,1:2]-LAnkle[:,1:2]))

    # Length of leg
    length_leg = np.maximum(length_leg_right, length_leg_left)

    # Length of body
    length_body = length_head + length_torso + length_leg
    
    # Check all samples have length_body of 0
    length_chk = (length_body > 0).astype(int)
    
    # Check keypoints at origin
    keypoints_chk = (X > 0).astype(int)
    
    chk = length_chk * keypoints_chk
    
    # Set all length_body of 0 to 1 (to avoid division by 0)
    length_body[length_body == 0] = 1
    
    # The center of gravity
    # number of point OpenPose locates:
    num_pts = (X[:, 0::2] > 0).sum(1).reshape(num_sample,1)
    centr_x = X[:, 0::2].sum(1).reshape(num_sample,1) / num_pts
    centr_y = X[:, 1::2].sum(1).reshape(num_sample,1) / num_pts

    # The  coordinates  are  normalized relative to the length of the body and the center of gravity
    X_norm_x = (X[:, 0::2] - centr_x) / length_body
    X_norm_y = (X[:, 1::2] - centr_y) / length_body
    
    # Stack 1st element x and y together
    X_norm = np.column_stack((X_norm_x[:,:1], X_norm_y[:,:1]))
        
    for i in range(1, X.shape[1]//2):
        X_norm = np.column_stack((X_norm, X_norm_x[:,i:i+1], X_norm_y[:,i:i+1]))
    
    # Set all samples have length_body of 0 to origin (0, 0)
    X_norm = X_norm * chk
    
    return X_norm

# %%
alpha_example
# Out:
# array([[621.59161377, 530.50286865, 606.00219727, 518.81085205,
#         609.89953613, 538.29754639, 578.72076416, 499.3241272 ,
#         594.31011963, 573.37371826, 559.23400879, 456.45330811,
#         613.79693604, 596.75775146, 547.54199219, 359.01959229,
#         660.56506348, 651.32061768, 539.74731445, 265.48327637,
#         707.33319092, 698.08880615, 676.15447998, 413.5824585 ,
#         715.12792969, 475.94000244, 746.30670166, 300.55938721,
#         812.56158447, 440.8638916 , 765.793396  , 304.45672607,
#         871.02178955, 378.50634766],
#        [621.59161377, 530.50286865, 606.00219727, 518.81085205,
#         609.89953613, 538.29754639, 578.72076416, 499.3241272 ,
#         594.31011963, 573.37371826, 559.23400879, 456.45330811,
#         613.79693604, 596.75775146, 547.54199219, 359.01959229,
#         660.56506348, 651.32061768, 539.74731445, 265.48327637,
#         707.33319092, 698.08880615, 676.15447998, 413.5824585 ,
#         715.12792969, 475.94000244, 746.30670166, 300.55938721,
#         812.56158447, 440.8638916 , 765.793396  , 304.45672607,
#         871.02178955, 378.50634766]])

# %%
alpha_norm=norm_alpha(alpha_example)

# %%
alpha_norm[0]
# Out:
# array([-0.10029696,  0.15489659, -0.14065324,  0.1246295 , -0.13056421,
#         0.17507465, -0.2112766 ,  0.07418427, -0.17092048,  0.26587623,
#        -0.26172191, -0.03679529, -0.12047502,  0.32641041, -0.291989  ,
#        -0.28902166,  0.00059349,  0.46765714, -0.31216706, -0.53115884,
#         0.121662  ,  0.58872581,  0.04094977, -0.14777493,  0.14184022,
#         0.01364986,  0.22255261, -0.44035742,  0.39406643, -0.07715156,
#         0.27299776, -0.43026839,  0.54540219, -0.23857635])

# %%
# Testing on single example

plot_alpha(alpha_example[0])
# Out:
# skeleton: [[621.59161377 530.50286865 606.00219727 518.81085205 609.89953613
#   538.29754639 578.72076416 499.3241272  594.31011963 573.37371826
#   559.23400879 456.45330811 613.79693604 596.75775146 547.54199219
#   359.01959229 660.56506348 651.32061768 539.74731445 265.48327637
#   707.33319092 698.08880615 676.15447998 413.5824585  715.12792969
#   475.94000244 746.30670166 300.55938721 812.56158447 440.8638916
#   765.793396   304.45672607 871.02178955 378.50634766]]
# Neck: [613.79690552 524.65686035]
# skeleton: [[-0.10029696  0.15489659 -0.14065324  0.1246295  -0.13056421  0.17507465
#   -0.2112766   0.07418427 -0.17092048  0.26587623 -0.26172191 -0.03679529
#   -0.12047502  0.32641041 -0.291989   -0.28902166  0.00059349  0.46765714
#   -0.31216706 -0.53115884  0.121662    0.58872581  0.04094977 -0.14777493
#    0.14184022  0.01364986  0.22255261 -0.44035742  0.39406643 -0.07715156
#    0.27299776 -0.43026839  0.54540219 -0.23857635]]
# Neck: [-0.1204751   0.13976304]

# %%
alpha_example
# Out:
# (34,)
